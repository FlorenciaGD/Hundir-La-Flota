# %%
''' Usando listas creo tres tableros de 10 filas y 10 columnas:
1. "tablero_jugador" posiciona los barcos del jugador
2. "tablero_computer" posiciona los barcos del ordenador
3. "tablero disparos" Aquí se verán los disparos del jugador '''

tablero_jugador = [[" " for i in range(10)] for j in range(10)]
tablero_computer = [[" " for i in range(10)] for j in range(10)]
tablero_disparos = [[" " for i in range(10)] for j in range(10)]


#Funcion para los tableros:

'''En la funcion "mostrar_barco" tiene como argumento un tablero
cuya función es mostrar el tablero con los disparos realizados por el jugador'''

def mostrar_tablero(tablero):
    for i in tablero:
        print(i)




# Colocación barcos en el tablero del jugador

#Barcos de 1 eslora
tablero_jugador[0][0] = "B"
tablero_jugador[2][2] = "B" 
tablero_jugador[4][4] = "B"
tablero_jugador[6][6] = "B"

#Barcos de 2 esloras
tablero_jugador[1][1] = "B"
tablero_jugador[1][2] = "B" 
tablero_jugador[3][3] = "B"
tablero_jugador[3][4] = "B"
tablero_jugador[5][5] = "B"
tablero_jugador[5][6] = "B"

#Barcos de 3 esloras
tablero_jugador[7][0] = "B"
tablero_jugador[7][1] = "B" 
tablero_jugador[7][2] = "B"
tablero_jugador[8][0] = "B"
tablero_jugador[8][1] = "B"
tablero_jugador[8][2] = "B"

#Barcos de 4 esloras
tablero_jugador[9][0] = "B"
tablero_jugador[9][1] = "B" 
tablero_jugador[9][2] = "B"
tablero_jugador[9][3] = "B"

# Colocación barcos en el tablero del ordenador

#Barcos de 1 eslora
tablero_computer[0][1] = "B"
tablero_computer[1][8] = "B" 
tablero_computer[3][9] = "B"
tablero_computer[3][4] = "B"

#Barcos de 2 esloras
tablero_computer[6][0] = "B"
tablero_computer[6][1] = "B" 
tablero_computer[2][1] = "B"
tablero_computer[2][2] = "B"
tablero_computer[9][4] = "B"
tablero_computer[9][5] = "B"

#Barcos de 3 esloras
tablero_computer[7][7] = "B"
tablero_computer[7][6] = "B" 
tablero_computer[7][5] = "B"
tablero_computer[0][6] = "B"
tablero_computer[0][4] = "B"
tablero_computer[0][5] = "B"

#Barcos de 4 esloras
tablero_computer[5][3] = "B"
tablero_computer[5][4] = "B" 
tablero_computer[5][5] = "B"
tablero_computer[5][6] = "B"
    
#FUNCIONES 

'''Turno jugador: Esta funcion pide al jugador que ingrese las coordenadas para disparar 
y comprueba si éstas son válidas y si ya se han disparado.
Va actualizando el tablero a medida que el jugador va disparando'''

'''En el bucle añado try y except por si el jugador ingresa una coordenada que no es un numero,
 en tal caso responderá con un "Por favor, ingresa coordenadas válidas". 
 Try ejecuta un código que podría darme error. Except ValueError captura el 
 error cuando el jugador introduce un valor que no es un número.'''

def turno_jugador():
    while True:
        try:
            fila = int(input("Ingresa la fila: "))
            columna = int(input("Ingresa la columna: "))
            if 0 <= fila <= 9 and 0<= columna <= 9:
                if tablero_disparos[fila][columna] == " ":       #Verifica que todavía no se haya disparado en esta posición
                    if tablero_computer[fila][columna] == "B":   #Verifica si en el tablero del ordenador hay un barco en esa posición
                        print("Yuhu! Le has dado a un barco!")
                        tablero_disparos[fila][columna] = "X"       
                        tablero_computer[fila][columna] = "X"
                        break
                    else:
                        print ("Agua!")
                        tablero_disparos[fila][columna] = "O"
                        break
                else:
                    print("Mal! Ya habías disparado aquí!")
            else:
                print("Coordenadas fuera de rango")
        except ValueError:
            print("Por favor, ingresa números válidos")


'''Turno Ordenador: Para esta función utilizo el módulo random para que en el turno de la 
computadora dispare de forma aleatoria'''
import random
def turno_computer():                                                               
    while True:
        fila = random.randint(0,9)
        columna = random.randint (0,9)
        if tablero_jugador[fila][columna] == "B":
            print(f"Te han dado en ({fila}, {columna})")
            tablero_jugador[fila][columna] = "X"
            break
        elif tablero_jugador[fila][columna] == " ":
            print(f"Computer te ha disparado en ({fila}, {columna})y falló.")
            tablero_jugador[fila][columna] = "O"
            break

#Comprobar si hay ganador
'''El ojetivo de esta función es ver si todos los barcos han sido hundidos
 recorriendo el tablero y comprobando si quedan barcos. En caso de que no queden barcos 
 devuelve True'''
def barcos_hundidos(tablero):
    for fila in tablero:
        if "B" in fila:
            return False
        print("Has ganado! Has hundido todos los barcos! :)")
    return True

#Bucle del juego
'''En el bucle del juego se muestran los tableros del jugador y de disparos,
además va alternando entre el turno del jugador y el ordenador y verifica
si hay ganador
'''

print("Bienvenido a Hundir La Flota")
while True:
    print("Tu tablero:")
    mostrar_tablero(tablero_jugador)
    print("Tablero de disparos")
    mostrar_tablero(tablero_disparos)

    print("Tu turno:")
    turno_jugador()
    if barcos_hundidos(tablero_computer):
        print("Has ganado!")
        break
    print("Turno ordenador")
    turno_computer()
    if barcos_hundidos(tablero_jugador):
        print("El ordenador te ha dado una paliza! Game over!")
        break
# Out:
# Bienvenido a Hundir La Flota
# Tu tablero:
# ['B', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', 'B', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', 'B', 'B', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', 'B', ' ', ' ', ' ']
# ['B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['B', 'B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# Tablero de disparos
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# Tu turno:
# Yuhu! Le has dado a un barco!
# Turno ordenador
# Computer te ha disparado en (0, 9)y falló.
# Tu tablero:
# ['B', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'O']
# [' ', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', 'B', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', 'B', 'B', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', 'B', ' ', ' ', ' ']
# ['B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['B', 'B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# Tablero de disparos
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', 'X', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# Tu turno:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 152
#     149 mostrar_tablero(tablero_disparos)
#     151 print("Tu turno:")
# --> 152 turno_jugador()
#     153 if barcos_hundidos(tablero_computer):
#     154     print("Has ganado!")
#
# Cell In[2], line 91, in turno_jugador()
#      88 def turno_jugador():
#      89     while True:
#      90         #try:
# ---> 91             fila = int(input("Ingresa la fila: "))
#      92             columna = int(input("Ingresa la columna: "))
#      93             if 0 <= fila <= 9 and 0<= columna <= 9:
#
# ValueError: invalid literal for int() with base 10: 'h'
